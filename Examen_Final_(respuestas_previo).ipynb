# %% [markdown]
# # Respuestas

# %% [markdown]
# 1. Utiliza la función adecuada de pandas para convertir los nombres de la columna `Name` a un formato donde la primera letra tanto del nombre y del apellido esté en mayúsculas, por ejemplo Evgenia Medvedeva.

# %%
# Out:
#                Nombre            Pais    Sexo     FechaNacimiento  Ganancias  \
# 0   Evgenia Medvedeva           Rusia   Mujer  Noviembre 19, 1999       4306
# 1   Gabrielle Daleman          Canada   Mujer      Junio 13, 1998       2724
# 2         Jason Brown  Estados Unidos  Hombre  Diciembre 15, 1994       3674
# 3      Alina Zagitova           Rusia   Mujer       Mayo 18, 2002       5320
# 4    Carolina Kostner          Italia   Mujer     Febrero 8, 1987       3212
# 5        Matteo Rizzo          Italia  Hombre  Septiembre 5, 1998       3094
# 6        Yuzuru Hanyu           Japon  Hombre   Diciembre 7, 1994       4780
# 7        Mirai Nagasu  Estados Unidos   Mujer      Abril 16, 1993       2066
# 8         Nathan Chen  Estados Unidos  Hombre        Mayo 5, 1999       5414
# 9           Shoma Uno           Japon  Hombre  Diciembre 17, 1997       5059
# 10       Dmitri Aliev           Rusia  Hombre       Junio 1, 1999       3063
# ...

# %% [markdown]
# 2. Escribe una función llamada `ganancias` que reciba de parámetro una variable `total` (que es un número) y *regrese* un string de acuerdo con las siguientes condiciones:
#
# - Si el número es MENOR a 3,100 regresa "Ganancias bajas"
# - Si el número es MAYOR O IGUAL a 3,100 Y MENOR a 4,500 regresa "Ganancias medias"
# - En cualquier otro caso regresa "Ganancias altas"

# %% [markdown]
# Crea una nueva columna llamada ```GananciasStr``` que aplique la función anterior sobre la columna `ComenzoPatinar`, y muestra el resultado.

# %%
# Out:
#                Nombre            Pais    Sexo     FechaNacimiento  Ganancias  \
# 0   Evgenia Medvedeva           Rusia   Mujer  Noviembre 19, 1999       4306
# 1   Gabrielle Daleman          Canada   Mujer      Junio 13, 1998       2724
# 2         Jason Brown  Estados Unidos  Hombre  Diciembre 15, 1994       3674
# 3      Alina Zagitova           Rusia   Mujer       Mayo 18, 2002       5320
# 4    Carolina Kostner          Italia   Mujer     Febrero 8, 1987       3212
# 5        Matteo Rizzo          Italia  Hombre  Septiembre 5, 1998       3094
# 6        Yuzuru Hanyu           Japon  Hombre   Diciembre 7, 1994       4780
# 7        Mirai Nagasu  Estados Unidos   Mujer      Abril 16, 1993       2066
# 8         Nathan Chen  Estados Unidos  Hombre        Mayo 5, 1999       5414
# 9           Shoma Uno           Japon  Hombre  Diciembre 17, 1997       5059
# 10       Dmitri Aliev           Rusia  Hombre       Junio 1, 1999       3063
# ...

# %% [markdown]
# 3. Utiliza una gráfica de contar para visualizar el total de elementos que hay en `Pais` y que además los divida por `Sexo` (hue).

# %% [markdown]
# 4. Utiliza una gráfica de barras para visualizar el promedio de la variable `Ganancias` (eje y) por `Sexo` (eje x).

# %% [markdown]
# 5. Ordena el conjunto de datos por la columna `Nombre` y guarda el resultado en la variable dataset (la idea es que a partir de ahora, el conjunto de datos se vea ordenado).

# %%
# Out:
#                Nombre            Pais    Sexo     FechaNacimiento  Ganancias  \
# 3      Alina Zagitova           Rusia   Mujer       Mayo 18, 2002       5320
# 4    Carolina Kostner          Italia   Mujer     Febrero 8, 1987       3212
# 10       Dmitri Aliev           Rusia  Hombre       Junio 1, 1999       3063
# 0   Evgenia Medvedeva           Rusia   Mujer  Noviembre 19, 1999       4306
# 1   Gabrielle Daleman          Canada   Mujer      Junio 13, 1998       2724
# 2         Jason Brown  Estados Unidos  Hombre  Diciembre 15, 1994       3674
# 12   Javier Fernandez          España  Hombre      Abril 15, 1991       3436
# 13     Kaetlyn Osmond          Canada   Mujer   Diciembre 5, 1995       4174
# 5        Matteo Rizzo          Italia  Hombre  Septiembre 5, 1998       3094
# 7        Mirai Nagasu  Estados Unidos   Mujer      Abril 16, 1993       2066
# 8         Nathan Chen  Estados Unidos  Hombre        Mayo 5, 1999       5414
# ...

# %% [markdown]
# ---

# %% [markdown]
# 6. Utilizando el conjunto de datos completo (dataset), escribe la instrucción adecuada de pandas para filtrar los datos de los patinadores con ganancias altas. Guarda el resultado en una variable e imprímela.

# %%
# Out:
#            Nombre            Pais    Sexo     FechaNacimiento  Ganancias  \
# 3  Alina Zagitova           Rusia   Mujer       Mayo 18, 2002       5320
# 8     Nathan Chen  Estados Unidos  Hombre        Mayo 5, 1999       5414
# 9       Shoma Uno           Japon  Hombre  Diciembre 17, 1997       5059
# 6    Yuzuru Hanyu           Japon  Hombre   Diciembre 7, 1994       4780
#
#    ComenzoPatinar     GananciasStr
# 3            2007  Ganancias altas
# 8            2002  Ganancias altas
# 9            2002  Ganancias altas
# 6            1998  Ganancias altas

# %% [markdown]
# 7. Escribe la instrucción adecuada de pandas para sumar todas las ganancias de los patinadores del subconunto anterior.

# %%
# Out:
# 20573

# %% [markdown]
# ---

# %% [markdown]
# 8. Utilizando el conjunto de datos completo (dataset), escribe la instrucción adecuada de pandas para filtrar los datos solamente de patinadores Mujeres (Sexo). Guarda el resultado en una variable e imprímela.

# %%
# Out:
#                Nombre            Pais   Sexo     FechaNacimiento  Ganancias  \
# 3      Alina Zagitova           Rusia  Mujer       Mayo 18, 2002       5320
# 4    Carolina Kostner          Italia  Mujer     Febrero 8, 1987       3212
# 0   Evgenia Medvedeva           Rusia  Mujer  Noviembre 19, 1999       4306
# 1   Gabrielle Daleman          Canada  Mujer      Junio 13, 1998       2724
# 13     Kaetlyn Osmond          Canada  Mujer   Diciembre 5, 1995       4174
# 7        Mirai Nagasu  Estados Unidos  Mujer      Abril 16, 1993       2066
# 11    Satoko Miyahara           Japon  Mujer      Marzo 26, 1998       4342
#
#     ComenzoPatinar      GananciasStr
# 3             2007   Ganancias altas
# 4             1990  Ganancias medias
# 0             2004  Ganancias medias
# 1             2002   Ganancias bajas
# 13            1998  Ganancias medias
# 7             1998   Ganancias bajas
# 11            2002  Ganancias medias

# %% [markdown]
# 9. Utiliza sobre el subconjunto anterior (o sea la variable solamente con los resultados de las patinadoras) obten los datos de la patinadora con mayores ganancias.

# %%
# Out:
#            Nombre   Pais   Sexo FechaNacimiento  Ganancias  ComenzoPatinar  \
# 3  Alina Zagitova  Rusia  Mujer   Mayo 18, 2002       5320            2007
#
#       GananciasStr
# 3  Ganancias altas

# %% [markdown]
# ---

# %% [markdown]
# 10. Utilizando el conjunto de datos completo (dataset), escribe la instrucción adecuada para filtrar los datos que cumplan con las siguientes condiciones:
#
# *   Sex es Hombre y
# *   Ganancias es mayor a 2500 y
# *   ComenzoPatinar es mayor a 2000.
#
# Guarda el resultado en una variable e imprímela.

# %%
# Out:
#           Nombre            Pais    Sexo     FechaNacimiento  Ganancias  \
# 10  Dmitri Aliev           Rusia  Hombre       Junio 1, 1999       3063
# 5   Matteo Rizzo          Italia  Hombre  Septiembre 5, 1998       3094
# 8    Nathan Chen  Estados Unidos  Hombre        Mayo 5, 1999       5414
# 9      Shoma Uno           Japon  Hombre  Diciembre 17, 1997       5059
#
#     ComenzoPatinar     GananciasStr
# 10            2005  Ganancias bajas
# 5             2006  Ganancias bajas
# 8             2002  Ganancias altas
# 9             2002  Ganancias altas

# %% [markdown]
# 11. Utilizando el resultado del punto 10, obtén solamente los datos cuyo año de nacimiento sea 1999

# %%
# Out:
#           Nombre            Pais    Sexo FechaNacimiento  Ganancias  \
# 10  Dmitri Aliev           Rusia  Hombre   Junio 1, 1999       3063
# 8    Nathan Chen  Estados Unidos  Hombre    Mayo 5, 1999       5414
#
#     ComenzoPatinar     GananciasStr
# 10            2005  Ganancias bajas
# 8             2002  Ganancias altas

# %% [markdown]
# 12. Utilizando el resultado del punto 10, grafica las ganancias de los patinadores con una gráfica de barras. Eje x (Nombre), Eje y (Ganancias)
