# %% [markdown]
# # Respuestas

# %% [markdown]
# 1. Utiliza la función adecuada de pandas para convertir los nombres de la columna `Name` a un formato donde la primera letra tanto del nombre y del apellido esté en mayúsculas, por ejemplo Evgenia Medvedeva.

# %%
# Out:
#                Nombre            Pais    Sexo    FechaNacimiento  Ganancias  \
# 0   Evgenia Medvedeva           Rusia   Mujer  Noviembre-19-1999       4306
# 1   Gabrielle Daleman          Canada   Mujer      Junio-13-1998       2724
# 2         Jason Brown  Estados Unidos  Hombre  Diciembre-15-1994       3674
# 3      Alina Zagitova           Rusia   Mujer       Mayo-18-2002       5320
# 4    Carolina Kostner          Italia   Mujer     Febrero-8-1987       3212
# 5        Matteo Rizzo          Italia  Hombre  Septiembre-5-1998       3094
# 6        Yuzuru Hanyu           Japon  Hombre   Diciembre-7-1994       4780
# 7        Mirai Nagasu  Estados Unidos   Mujer      Abril-16-1993       2066
# 8         Nathan Chen  Estados Unidos  Hombre       Marzo-5-1999       5414
# 9           Shoma Uno           Japon  Hombre  Diciembre-17-1997       5059
# 10       Dmitri Aliev           Rusia  Hombre       Junio-1-1999       3063
# ...

# %% [markdown]
# 2. Ordena el conjunto de datos por la columna `Nombre` y guarda el resultado en la variable `dataset` (la idea es que a partir de ahora, el conjunto de datos se vea ordenado).

# %%
# Out:
#                Nombre            Pais    Sexo    FechaNacimiento  Ganancias  \
# 3      Alina Zagitova           Rusia   Mujer       Mayo-18-2002       5320
# 4    Carolina Kostner          Italia   Mujer     Febrero-8-1987       3212
# 10       Dmitri Aliev           Rusia  Hombre       Junio-1-1999       3063
# 0   Evgenia Medvedeva           Rusia   Mujer  Noviembre-19-1999       4306
# 1   Gabrielle Daleman          Canada   Mujer      Junio-13-1998       2724
# 2         Jason Brown  Estados Unidos  Hombre  Diciembre-15-1994       3674
# 12   Javier Fernandez          España  Hombre      Abril-15-1991       3436
# 13     Kaetlyn Osmond          Canada   Mujer   Diciembre-5-1995       4174
# 5        Matteo Rizzo          Italia  Hombre  Septiembre-5-1998       3094
# 7        Mirai Nagasu  Estados Unidos   Mujer      Abril-16-1993       2066
# 8         Nathan Chen  Estados Unidos  Hombre       Marzo-5-1999       5414
# ...

# %% [markdown]
# 3. Escribe una función llamada `obtenerAño` que reciba de parámetro una variable `texto`, que corresponde a un string con la fecha de nacimiento en formato mm-dia-año (nota los guiones de separación). Por ejemplo: Diciembre-15-1994, la función *regresa* solamente el año convertido a entero.

# %% [markdown]
# Crea una nueva columna llamada `AñoNacimiento` que aplique la función anterior sobre la columna `FechaNacimiento`, y muestra el resultado.

# %%
# Out:
#                Nombre            Pais    Sexo    FechaNacimiento  Ganancias  \
# 3      Alina Zagitova           Rusia   Mujer       Mayo-18-2002       5320
# 4    Carolina Kostner          Italia   Mujer     Febrero-8-1987       3212
# 10       Dmitri Aliev           Rusia  Hombre       Junio-1-1999       3063
# 0   Evgenia Medvedeva           Rusia   Mujer  Noviembre-19-1999       4306
# 1   Gabrielle Daleman          Canada   Mujer      Junio-13-1998       2724
# 2         Jason Brown  Estados Unidos  Hombre  Diciembre-15-1994       3674
# 12   Javier Fernandez          España  Hombre      Abril-15-1991       3436
# 13     Kaetlyn Osmond          Canada   Mujer   Diciembre-5-1995       4174
# 5        Matteo Rizzo          Italia  Hombre  Septiembre-5-1998       3094
# 7        Mirai Nagasu  Estados Unidos   Mujer      Abril-16-1993       2066
# 8         Nathan Chen  Estados Unidos  Hombre       Marzo-5-1999       5414
# ...

# %% [markdown]
# 4.  Crea una nueva columna llamada `EdadActual` que sea el resultado de restar 2020 menos la columna `AñoNacimiento`, y muestra el resultado.

# %%
# Out:
#                Nombre            Pais    Sexo    FechaNacimiento  Ganancias  \
# 3      Alina Zagitova           Rusia   Mujer       Mayo-18-2002       5320
# 4    Carolina Kostner          Italia   Mujer     Febrero-8-1987       3212
# 10       Dmitri Aliev           Rusia  Hombre       Junio-1-1999       3063
# 0   Evgenia Medvedeva           Rusia   Mujer  Noviembre-19-1999       4306
# 1   Gabrielle Daleman          Canada   Mujer      Junio-13-1998       2724
# 2         Jason Brown  Estados Unidos  Hombre  Diciembre-15-1994       3674
# 12   Javier Fernandez          España  Hombre      Abril-15-1991       3436
# 13     Kaetlyn Osmond          Canada   Mujer   Diciembre-5-1995       4174
# 5        Matteo Rizzo          Italia  Hombre  Septiembre-5-1998       3094
# 7        Mirai Nagasu  Estados Unidos   Mujer      Abril-16-1993       2066
# 8         Nathan Chen  Estados Unidos  Hombre       Marzo-5-1999       5414
# ...

# %% [markdown]
# 5.  Crea una nueva columna llamada `EdadComenzoPatinar` que sea el resultado de restar la columna `ComenzoPatinar` menos la columna `AñoNacimiento`, y muestra el resultado.

# %%
# Out:
#                Nombre            Pais    Sexo    FechaNacimiento  Ganancias  \
# 3      Alina Zagitova           Rusia   Mujer       Mayo-18-2002       5320
# 4    Carolina Kostner          Italia   Mujer     Febrero-8-1987       3212
# 10       Dmitri Aliev           Rusia  Hombre       Junio-1-1999       3063
# 0   Evgenia Medvedeva           Rusia   Mujer  Noviembre-19-1999       4306
# 1   Gabrielle Daleman          Canada   Mujer      Junio-13-1998       2724
# 2         Jason Brown  Estados Unidos  Hombre  Diciembre-15-1994       3674
# 12   Javier Fernandez          España  Hombre      Abril-15-1991       3436
# 13     Kaetlyn Osmond          Canada   Mujer   Diciembre-5-1995       4174
# 5        Matteo Rizzo          Italia  Hombre  Septiembre-5-1998       3094
# 7        Mirai Nagasu  Estados Unidos   Mujer      Abril-16-1993       2066
# 8         Nathan Chen  Estados Unidos  Hombre       Marzo-5-1999       5414
# ...

# %% [markdown]
# 6. Escribe una función llamada `obtenerContinente` que reciba de parámetro una variable `pais`, que corresponde a un string con el nombre de un país y *regrese* un string dependiendo de las siguientes condiciones:
#
# - Si el pais es Italia, España o Rusia *regresa* Europa
# - Si el pais es Canada o Estados Unidos *regresa* Americ
# - Si el pais es Japon *regresa* Asia
# - En cualquier otro caso, *regresa* Otro

# %% [markdown]
# Crea una nueva columna llamada `Continente` que aplique la función anterior sobre la columna `Pais`, y muestra el resultado.

# %%
# Out:
#                Nombre            Pais    Sexo    FechaNacimiento  Ganancias  \
# 3      Alina Zagitova           Rusia   Mujer       Mayo-18-2002       5320
# 4    Carolina Kostner          Italia   Mujer     Febrero-8-1987       3212
# 10       Dmitri Aliev           Rusia  Hombre       Junio-1-1999       3063
# 0   Evgenia Medvedeva           Rusia   Mujer  Noviembre-19-1999       4306
# 1   Gabrielle Daleman          Canada   Mujer      Junio-13-1998       2724
# 2         Jason Brown  Estados Unidos  Hombre  Diciembre-15-1994       3674
# 12   Javier Fernandez          España  Hombre      Abril-15-1991       3436
# 13     Kaetlyn Osmond          Canada   Mujer   Diciembre-5-1995       4174
# 5        Matteo Rizzo          Italia  Hombre  Septiembre-5-1998       3094
# 7        Mirai Nagasu  Estados Unidos   Mujer      Abril-16-1993       2066
# 8         Nathan Chen  Estados Unidos  Hombre       Marzo-5-1999       5414
# ...

# %% [markdown]
# 7. Utiliza una gráfica de contar para visualizar el total de elementos que hay en `Continente` y que además los divida por `Sexo` (hue).

# %% [markdown]
# 8. Utiliza una gráfica de barras para visualizar el promedio de la variable `EdadComenzoPatinar` (eje y) y `Sexo` (eje x).

# %% [markdown]
# ---

# %% [markdown]
# 9. Utilizando el conjunto de datos completo (dataset), escribe la instrucción adecuada de pandas para filtrar los datos solamente de patinadores Mujeres (Sexo). Guarda el resultado en una variable e imprímela.

# %%
# Out:
#                Nombre            Pais   Sexo    FechaNacimiento  Ganancias  \
# 3      Alina Zagitova           Rusia  Mujer       Mayo-18-2002       5320
# 4    Carolina Kostner          Italia  Mujer     Febrero-8-1987       3212
# 0   Evgenia Medvedeva           Rusia  Mujer  Noviembre-19-1999       4306
# 1   Gabrielle Daleman          Canada  Mujer      Junio-13-1998       2724
# 13     Kaetlyn Osmond          Canada  Mujer   Diciembre-5-1995       4174
# 7        Mirai Nagasu  Estados Unidos  Mujer      Abril-16-1993       2066
# 11    Satoko Miyahara           Japon  Mujer      Marzo-26-1998       4342
#
#     ComenzoPatinar  AñoNacimiento  EdadActual  EdadComenzoPatinar Continente
# 3             2007           2002          18                   5     Europa
# 4             1990           1987          33                   3     Europa
# 0             2004           1999          21                   5     Europa
# ...

# %% [markdown]
# 10. Utiliza sobre el subconjunto anterior (o sea la variable solamente con los resultados de las patinadoras) obten los datos de la patinadora con la edad más chica en que comenzó a patinar (`EdadComenzoPatinar`), y muestra el resultado.

# %%
# Out:
#               Nombre    Pais   Sexo   FechaNacimiento  Ganancias  \
# 4   Carolina Kostner  Italia  Mujer    Febrero-8-1987       3212
# 13    Kaetlyn Osmond  Canada  Mujer  Diciembre-5-1995       4174
#
#     ComenzoPatinar  AñoNacimiento  EdadActual  EdadComenzoPatinar Continente
# 4             1990           1987          33                   3     Europa
# 13            1998           1995          25                   3    America

# %% [markdown]
# ---

# %% [markdown]
# 11. Utilizando el conjunto de datos completo (dataset), escribe la instrucción adecuada de pandas para obtener el promedio de las `Ganancias`, guarda el resultado en una variable (e.g. promGan) e imprímela.

# %%
# Out:
# 3904.5714285714284

# %% [markdown]
# Ahora escribe la instrucción adecuada de pandas para filtrar los datos de los patinadores con ganancias MENORES al promedio obtenido arriba O cuyo Pais TERMINE con la letra 'a'. Guarda el resultado en una variable e imprímela.

# %%
# Out:
#                Nombre            Pais    Sexo    FechaNacimiento  Ganancias  \
# 3      Alina Zagitova           Rusia   Mujer       Mayo-18-2002       5320
# 4    Carolina Kostner          Italia   Mujer     Febrero-8-1987       3212
# 10       Dmitri Aliev           Rusia  Hombre       Junio-1-1999       3063
# 0   Evgenia Medvedeva           Rusia   Mujer  Noviembre-19-1999       4306
# 1   Gabrielle Daleman          Canada   Mujer      Junio-13-1998       2724
# 2         Jason Brown  Estados Unidos  Hombre  Diciembre-15-1994       3674
# 12   Javier Fernandez          España  Hombre      Abril-15-1991       3436
# 13     Kaetlyn Osmond          Canada   Mujer   Diciembre-5-1995       4174
# 5        Matteo Rizzo          Italia  Hombre  Septiembre-5-1998       3094
# 7        Mirai Nagasu  Estados Unidos   Mujer      Abril-16-1993       2066
#
#     ComenzoPatinar  AñoNacimiento  EdadActual  EdadComenzoPatinar Continente
# ...

# %% [markdown]
# 12. Escribe la instrucción adecuada de pandas para sumar todas las ganancias de los patinadores del subconunto anterior.

# %%
# Out:
# 35069

# %% [markdown]
# ---

# %% [markdown]
# 13. Utilizando el conjunto de datos completo (dataset), escribe la instrucción adecuada para filtrar los datos que cumplan con las siguientes condiciones:
# *   Ganancias es mayor a 3500 Y
# *   EdadActual es mayor o igual a 20.
#
# Guarda el resultado en una variable e imprímela.

# %%
# Out:
#                Nombre            Pais    Sexo    FechaNacimiento  Ganancias  \
# 0   Evgenia Medvedeva           Rusia   Mujer  Noviembre-19-1999       4306
# 2         Jason Brown  Estados Unidos  Hombre  Diciembre-15-1994       3674
# 13     Kaetlyn Osmond          Canada   Mujer   Diciembre-5-1995       4174
# 8         Nathan Chen  Estados Unidos  Hombre       Marzo-5-1999       5414
# 11    Satoko Miyahara           Japon   Mujer      Marzo-26-1998       4342
# 9           Shoma Uno           Japon  Hombre  Diciembre-17-1997       5059
# 6        Yuzuru Hanyu           Japon  Hombre   Diciembre-7-1994       4780
#
#     ComenzoPatinar  AñoNacimiento  EdadActual  EdadComenzoPatinar Continente
# 0             2004           1999          21                   5     Europa
# 2             1999           1994          26                   5    America
# 13            1998           1995          25                   3    America
# ...

# %% [markdown]
# 14. Utilizando el resultado del punto 13, obtén solamente los datos de los patinadores cuyo mes de nacimiento sea 'Marzo'. Guarda el resultado en otra variable e imprímela.

# %%
# Out:
#              Nombre            Pais    Sexo FechaNacimiento  Ganancias  \
# 8       Nathan Chen  Estados Unidos  Hombre    Marzo-5-1999       5414
# 11  Satoko Miyahara           Japon   Mujer   Marzo-26-1998       4342
#
#     ComenzoPatinar  AñoNacimiento  EdadActual  EdadComenzoPatinar Continente
# 8             2002           1999          21                   3    America
# 11            2002           1998          22                   4       Asia

# %% [markdown]
# 15. Utilizando el resultado del punto 14 (anterior), grafica las ganancias de los patinadores con una gráfica de barras. Eje x (Nombre), Eje y (Ganancias)
